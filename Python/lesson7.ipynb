# %% [markdown]
# взаимодейтсвие с колегами алогоритм:
# 1)выбираем колегу для форка
# 2)выбираем репозиротий для форка, если не знаем какой выбрать репозиторий пишем в чат код ревью
# 3)клонируем репозиторий, создаем ветку  dev
# 4)пишем в чат git  @senatorov дай права и ссулку на репу,  до этого момента правки могу внисть только я
# 5)в vs code  выбрать операцию клонированию и склонироваться по ссылке
# 6)добавить коментарий в файлы
# 7)отдать все файлы общим комитом
# 8) пишем в чат код ревью @ дай ревью и ссылку на комит
